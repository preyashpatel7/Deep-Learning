# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.layers import *
from tensorflow.keras.models import * 
print('Imported Successfully!')
# Out:
# Imported Successfully!

# %%
train_datagen = image.ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
test_datagen = image.ImageDataGenerator(rescale = 1./255)

print('Created the Data Generator Objects.')
# Out:
# Created the Data Generator Objects.

# %%
train_generator = train_datagen.flow_from_directory('datasets/CovidDataset/Train',target_size=(224,224),batch_size=32, class_mode="binary")
val_generator = test_datagen.flow_from_directory('datasets/CovidDataset/Val',target_size=(224,224),batch_size=32, class_mode="binary")
# Out:
# Found 224 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), activation="relu",input_shape=(224,224,3)))
model.add(Conv2D(64, kernel_size=(3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Conv2D(128, kernel_size=(3,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(1, activation="sigmoid"))

model.compile(loss="binary_crossentropy", optimizer="adam",metrics = ["accuracy"])
model.summary()
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-12-29 09:53:25.891859: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2025-12-29 09:53:25.891900: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-12-29 09:53:25.892006: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-12-29 09:53:25.892048: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...

# %%
hist = model.fit(train_generator, epochs = 6, validation_data=val_generator, validation_steps=2)
# Out:
# Epoch 1/6
# 2025-12-29 09:54:55.145012: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 10s 873ms/step - accuracy: 0.5714 - loss: 9.3025 - val_accuracy: 0.9000 - val_loss: 0.2413
# Epoch 2/6
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 697ms/step - accuracy: 0.5804 - loss: 3.4114 - val_accuracy: 0.9333 - val_loss: 0.5975
# Epoch 3/6
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 756ms/step - accuracy: 0.7009 - loss: 0.7595 - val_accuracy: 0.9333 - val_loss: 0.3492
# Epoch 4/6
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 740ms/step - accuracy: 0.6964 - loss: 1.9482 - val_accuracy: 0.9500 - val_loss: 0.1958
# Epoch 5/6
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 701ms/step - accuracy: 0.6652 - loss: 2.8546 - val_accuracy: 0.9667 - val_loss: 0.1504
# Epoch 6/6
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 5s 731ms/step - accuracy: 0.7366 - loss: 2.0604 - val_accuracy: 0.9500 - val_loss: 0.1889
